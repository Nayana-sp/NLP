# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayana-sp/NLP/blob/main/NLPExp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 69.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# %%
text = "Apple is looking at buying U.K. startup for $1 billion. Elon Musk founded SpaceX in 2002."
doc = nlp(text)

print("Original Text:")
print(text)
# Out:
# Original Text:
# Apple is looking at buying U.K. startup for $1 billion. Elon Musk founded SpaceX in 2002.

# %% [markdown]
# #Tokenization

# %%
print(" Tokenization:")
tokens = [token.text for token in doc]
print(tokens)
# Out:
#  Tokenization:
# ['Apple', 'is', 'looking', 'at', 'buying', 'U.K.', 'startup', 'for', '$', '1', 'billion', '.', 'Elon', 'Musk', 'founded', 'SpaceX', 'in', '2002', '.']

# %% [markdown]
# #Stop Word Removal

# %%
print(" Stop Word Removal:")
filtered_tokens = [token.text for token in doc if not token.is_stop and not token.is_punct]
print(filtered_tokens)
# Out:
#  Stop Word Removal:
# ['Apple', 'looking', 'buying', 'U.K.', 'startup', '$', '1', 'billion', 'Elon', 'Musk', 'founded', 'SpaceX', '2002']

# %% [markdown]
# #Lemmatization (SpaCy)

# %%
print("Lemmatization:")
for token in doc:
    print(token.text, "→", token.lemma_)
# Out:
# Lemmatization:
# Apple → Apple
# is → be
# looking → look
# at → at
# buying → buy
# U.K. → U.K.
# startup → startup
# for → for
# $ → $
# 1 → 1
# billion → billion
# . → .
# Elon → Elon
# Musk → Musk
# founded → found
# SpaceX → SpaceX
# in → in
# 2002 → 2002
# . → .

# %% [markdown]
# #POS Tagging

# %%
print("POS Tagging:")
for token in doc:
    print(token.text, "→", token.pos_)
# Out:
# POS Tagging:
# Apple → PROPN
# is → AUX
# looking → VERB
# at → ADP
# buying → VERB
# U.K. → PROPN
# startup → VERB
# for → ADP
# $ → SYM
# 1 → NUM
# billion → NUM
# . → PUNCT
# Elon → PROPN
# Musk → PROPN
# founded → VERB
# SpaceX → PROPN
# in → ADP
# 2002 → NUM
# . → PUNCT

# %% [markdown]
# #Named Entity Recognition (NER)

# %%
print(" Named Entity Recognition:")
for ent in doc.ents:
    print(ent.text, "→", ent.label_)
# Out:
#  Named Entity Recognition:
# Apple → ORG
# U.K. → GPE
# $1 billion → MONEY
# Elon Musk → PERSON
# 2002 → DATE

# %% [markdown]
# #Sentence Segmentation

# %%
print("Sentence Segmentation:")
for sent in doc.sents:
    print(sent.text)
# Out:
# Sentence Segmentation:
# Apple is looking at buying U.K. startup for $1 billion.
# Elon Musk founded SpaceX in 2002.

# %% [markdown]
# #REDUNDANT CLEANING

# %%
clean_tokens = [
    token.text
    for token in doc
    if not token.is_punct and not token.is_space
]

clean_text = " ".join(clean_tokens)

print("Cleaned Text:")
print(clean_text)
# Out:
# Cleaned Text:
# Apple is looking at buying U.K. startup for $ 1 billion Elon Musk founded SpaceX in 2002
